# %%
#import library
import pandas as pd

# %%
#import dataset
df=pd.read_csv("mtcars.csv")
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#view the dataset with top 10 rows
df.head(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
#view the dimenstionality of dataset
df.shape
# Out:
# (32, 12)

# %%
#view the type of dataset
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#view the columns of the dataset
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df["model"].dtype
# Out:
# dtype('O')

# %%
#identify the datatype of column hp
df["hp"].dtype
# Out:
# dtype('int64')

# %%
#use loc method to get specific columns
df.loc[:,("mpg","hp")].head(10)
# Out:
#     mpg   hp
# 0  21.0  110
# 1  21.0  110
# 2  22.8   93
# 3  21.4  110
# 4  18.7  175
# 5  18.1  105
# 6  14.3  245
# 7  24.4   62
# 8  22.8   95
# 9  19.2  123

# %%
#use iloc method to get the relavant columns with indexes.
df.iloc[:,0:5].head(16)
# Out:
#                   model   mpg  cyl   disp   hp
# 0             Mazda RX4  21.0    6  160.0  110
# 1         Mazda RX4 Wag  21.0    6  160.0  110
# 2            Datsun 710  22.8    4  108.0   93
# 3        Hornet 4 Drive  21.4    6  258.0  110
# 4     Hornet Sportabout  18.7    8  360.0  175
# 5               Valiant  18.1    6  225.0  105
# 6            Duster 360  14.3    8  360.0  245
# 7             Merc 240D  24.4    4  146.7   62
# 8              Merc 230  22.8    4  140.8   95
# 9              Merc 280  19.2    6  167.6  123
# 10            Merc 280C  17.8    6  167.6  123
# 11           Merc 450SE  16.4    8  275.8  180
# 12           Merc 450SL  17.3    8  275.8  180
# 13          Merc 450SLC  15.2    8  275.8  180
# 14   Cadillac Fleetwood  10.4    8  472.0  205
# 15  Lincoln Continental  10.4    8  460.0  215

# %%
#identify the realvant columns
df[["mpg","hp"]].head(10)
# Out:
#     mpg   hp
# 0  21.0  110
# 1  21.0  110
# 2  22.8   93
# 3  21.4  110
# 4  18.7  175
# 5  18.1  105
# 6  14.3  245
# 7  24.4   62
# 8  22.8   95
# 9  19.2  123

# %%
#identify the unique values of the dataset column hp
df['hp'].unique()
# Out:
# array([110,  93, 175, 105, 245,  62,  95, 123, 180, 205, 215, 230,  66,
#         52,  65,  97, 150,  91, 113, 264, 335, 109], dtype=int64)

# %%
#identify the all values of the specified column
df["hp"].values
# Out:
# array([110, 110,  93, 110, 175, 105, 245,  62,  95, 123, 123, 180, 180,
#        180, 205, 215, 230,  66,  52,  65,  97, 150, 150, 245, 175,  66,
#         91, 113, 264, 175, 335, 109], dtype=int64)

# %%
#identify the mean of the dataset to each column
df.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
#identify the median of the dataset
df.median()
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
#to return mode values of the dataset
df.mode(axis=0)
# Out:
#                   model   mpg  cyl   disp     hp  drat    wt   qsec   vs   am  \
# 0           AMC Javelin  10.4  8.0  275.8  110.0  3.07  3.44  17.02  0.0  0.0
# 1    Cadillac Fleetwood  15.2  NaN    NaN  175.0  3.92   NaN  18.90  NaN  NaN
# 2            Camaro Z28  19.2  NaN    NaN  180.0   NaN   NaN    NaN  NaN  NaN
# 3     Chrysler Imperial  21.0  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 4            Datsun 710  21.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 5      Dodge Challenger  22.8  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 6            Duster 360  30.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 7          Ferrari Dino   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 8              Fiat 128   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 9             Fiat X1-9   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 10       Ford Pantera L   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# ...

# %%
#correalation of the spedified columns
df[["mpg","hp"]].corr()
# Out:
#           mpg        hp
# mpg  1.000000 -0.776168
# hp  -0.776168  1.000000

# %%
print("Successfully completed the project on Automobile DataExploration")
# Out:
# Successfully completed the project on Automobile DataExploration

# %%
print("Thank you Simplilearn")
# Out:
# Thank you Simplilearn
