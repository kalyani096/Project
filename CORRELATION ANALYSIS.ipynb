# %%
#import libraries
import pandas as pd

# %%
#importing datset
df=pd.readf=pd.read_csv("middle_tn_schools.csv")
df
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# ..                            ...            ...    ...            ...
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
#to view the path of the file
pwd
# Out:
# 'C:\\Users\\Dell'

# %%
#view the dataset with first 10rows.
df.head(10)
# Out:
#                              name  school_rating    size  reduced_lunch  \
# 0     Allendale Elementary School            5.0   851.0           10.0
# 1             Anderson Elementary            2.0   412.0           71.0
# 2                Avoca Elementary            4.0   482.0           43.0
# 3                   Bailey Middle            0.0   394.0           91.0
# 4             Barfield Elementary            4.0   948.0           26.0
# 5  Barkers Mill Elementary School            4.0   893.0           48.0
# 6            Barksdale Elementary            4.0   580.0           58.0
# 7                Beech Elementary            5.0   612.0           16.0
# 8        Beech Senior High School            4.0  1274.0           21.0
# 9                 Bellevue Middle            3.0   680.0           50.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# ...

# %%
#identify the columns of the dataset.
df.columns
# Out:
# Index(['name', 'school_rating', 'size', 'reduced_lunch', 'state_percentile_16',
#        'state_percentile_15', 'stu_teach_ratio', 'school_type', 'avg_score_15',
#        'avg_score_16', 'full_time_teachers', 'percent_black', 'percent_white',
#        'percent_asian', 'percent_hispanic'],
#       dtype='object')

# %%
#extract the these columns.
df[["reduced_lunch","school_rating"]]
# Out:
#      reduced_lunch  school_rating
# 0             10.0            5.0
# 1             71.0            2.0
# 2             43.0            4.0
# 3             91.0            0.0
# 4             26.0            4.0
# ..             ...            ...
# 342           57.0            3.0
# 343            8.0            5.0
# 344           55.0            4.0
# 345            2.0            5.0
# 346           89.0            0.0
#
# [347 rows x 2 columns]

# %%
#extract the relavant variables
#examine the statistic applied to relavant variables.

df[["reduced_lunch","school_rating"]].groupby(["school_rating"]).describe().unstack()
# Out:
#                       school_rating
# reduced_lunch  count  0.0              43.000000
#                       1.0              40.000000
#                       2.0              44.000000
#                       3.0              56.000000
#                       4.0              86.000000
#                       5.0              78.000000
#                mean   0.0              83.581395
#                       1.0              74.950000
#                       2.0              64.272727
#                       3.0              50.285714
#                       4.0              41.000000
#                       5.0              21.602564
#                std    0.0               8.813498
#                       1.0              11.644191
#                       2.0              11.956051
#                       3.0              13.550866
#                       4.0              16.681092
#                       5.0              17.651268
# ...

# %%
#examine the correlation between the variables.
df[["reduced_lunch","school_rating"]].corr()
# Out:
#                reduced_lunch  school_rating
# reduced_lunch       1.000000      -0.815757
# school_rating      -0.815757       1.000000

# %%
print("sucessfully completed the project on Correlation analysis")
# Out:
# sucessfully completed the project on Correlation analysis

# %%
print("Thank you")
# Out:
# Thank you
