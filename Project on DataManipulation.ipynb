# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Salaries.csv")
df
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# ...

# %%
df.head(6)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6     DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# ...

# %%
df.tail(4)
# Out:
#             Id    EmployeeName                     JobTitle  BasePay  \
# 148644  148648  Joann Anderson  Communications Dispatcher 2      0.0
# 148645  148649     Leon Walker                    Custodian      0.0
# 148646  148650   Roy I Tillery                    Custodian      0.0
# 148647  148654       Joe Lopez   Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148644          0.0      0.00       0.0      0.00              0.00  2014
# 148645          0.0      0.00       0.0      0.00              0.00  2014
# 148646          0.0      0.00       0.0      0.00              0.00  2014
# 148647          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency Status
# 148644    NaN  San Francisco     PT
# 148645    NaN  San Francisco     PT
# 148646    NaN  San Francisco     PT
# 148647    NaN  San Francisco     PT

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 'NATHANIEL FORD',
#         'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', ..., nan,
#         'San Francisco', nan],
#        [2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', ..., nan,
#         'San Francisco', nan],
#        [3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', ..., nan,
#         'San Francisco', nan],
#        ...,
#        [148649, 'Leon Walker', 'Custodian', ..., nan, 'San Francisco',
#         'PT'],
#        [148650, 'Roy I Tillery', 'Custodian', ..., nan, 'San Francisco',
#         'PT'],
#        [148654, 'Joe Lopez', 'Counselor, Log Cabin Ranch', ..., nan,
#         'San Francisco', 'PT']], dtype=object)

# %%
df.isna().any()
# Out:
# Id                  False
# EmployeeName        False
# JobTitle            False
# BasePay              True
# OvertimePay         False
# OtherPay            False
# Benefits             True
# TotalPay            False
# TotalPayBenefits    False
# Year                False
# Notes                True
# Agency              False
# Status               True
# dtype: bool

# %%
df.shape
# Out:
# (148648, 13)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148643                       Human Services Technician       0.00
# ...

# %%
#df1=pd.DataFrame({'EmployeeName':["NATHANIEL FORD","Carolyn A Wilson","Joann Anderson","Roy I Tillery","Joe Lopez"],
             #"JobTitle":["GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY","Human Services Technician","Communications Dispatcher 2","Custodian","Counselor"],
    
             #"TotalPay":[567595.43,0.00,0.00,0.00,-618.13]})

        #df1=pd.DataFrame(np.arange(12).reshape(3,4),columns=["EmployeeName","JobTitle","TotalPay"])

# %%
df1.groupby(["EmployeeName","JobTitle","TotalPay"]).groups
# Out:
# {('Carolyn A Wilson', 'Human Services Technician', 0.0): [1], ('Joann Anderson', 'Communications Dispatcher 2', 0.0): [2], ('Joe Lopez', 'Counselor', -618.13): [4], ('NATHANIEL FORD', 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 567595.43): [0], ('Roy I Tillery', 'Custodian', 0.0): [3]}

# %%
emp_agency={'EmployeeName':["NATHANIEL FORD","Carolyn A Wilson","Joann Anderson","Roy I Tillery","Joe Lopez"],
                 "Agency":["San Francisco","San Francisco","San Francisco","San Francisco","San Francisco"]}
emp_agency
#df2=pd.DataFrame(emp_agency)
# Out:
# {'EmployeeName': ['NATHANIEL FORD',
#   'Carolyn A Wilson',
#   'Joann Anderson',
#   'Roy I Tillery',
#   'Joe Lopez'],
#  'Agency': ['San Francisco',
#   'San Francisco',
#   'San Francisco',
#   'San Francisco',
#   'San Francisco']}

# %%
df.size
# Out:
# 1932424

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df[["EmployeeName","JobTitle","TotalPay"]].head(10)
df1
# Out:
#          EmployeeName                                        JobTitle  \
# 0      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#     TotalPay
# 0  567595.43
# 1  538909.28
# 2  335279.91
# 3  332343.61
# 4  326373.19
# 5  316285.74
# 6  315981.05
# 7  307899.46
# 8  303427.55
# 9  302377.73

# %%
df2=df[["EmployeeName","Agency"]].head(10)
df2
# Out:
#          EmployeeName         Agency
# 0      NATHANIEL FORD  San Francisco
# 1        GARY JIMENEZ  San Francisco
# 2      ALBERT PARDINI  San Francisco
# 3   CHRISTOPHER CHONG  San Francisco
# 4     PATRICK GARDNER  San Francisco
# 5      DAVID SULLIVAN  San Francisco
# 6           ALSON LEE  San Francisco
# 7       DAVID KUSHNER  San Francisco
# 8      MICHAEL MORRIS  San Francisco
# 9  JOANNE HAYES-WHITE  San Francisco

# %%
pd.concat([df1,df2],axis=1).head(16)
# Out:
#          EmployeeName                                        JobTitle  \
# 0      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#     TotalPay        EmployeeName         Agency
# 0  567595.43      NATHANIEL FORD  San Francisco
# 1  538909.28        GARY JIMENEZ  San Francisco
# 2  335279.91      ALBERT PARDINI  San Francisco
# ...

# %%
pd.merge(df1,df2,on="EmployeeName")
# Out:
#          EmployeeName                                        JobTitle  \
# 0      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#     TotalPay         Agency
# 0  567595.43  San Francisco
# 1  538909.28  San Francisco
# 2  335279.91  San Francisco
# 3  332343.61  San Francisco
# 4  326373.19  San Francisco
# ...

# %%
pd.merge(df1,df2,on="EmployeeName",how="left")
# Out:
#          EmployeeName                                        JobTitle  \
# 0      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#     TotalPay         Agency
# 0  567595.43  San Francisco
# 1  538909.28  San Francisco
# 2  335279.91  San Francisco
# 3  332343.61  San Francisco
# 4  326373.19  San Francisco
# ...

# %%
pd.merge(df1,df2,on="EmployeeName",how="right")
# Out:
#          EmployeeName                                        JobTitle  \
# 0      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#     TotalPay         Agency
# 0  567595.43  San Francisco
# 1  538909.28  San Francisco
# 2  335279.91  San Francisco
# 3  332343.61  San Francisco
# 4  326373.19  San Francisco
# ...

# %%
pd.merge(df1,df2,on="EmployeeName",how="inner")
# Out:
#          EmployeeName                                        JobTitle  \
# 0      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#     TotalPay         Agency
# 0  567595.43  San Francisco
# 1  538909.28  San Francisco
# 2  335279.91  San Francisco
# 3  332343.61  San Francisco
# 4  326373.19  San Francisco
# ...

# %%
pd.merge(df1,df2,on="EmployeeName",how="outer")
# Out:
#          EmployeeName                                        JobTitle  \
# 0      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#     TotalPay         Agency
# 0  567595.43  San Francisco
# 1  538909.28  San Francisco
# 2  335279.91  San Francisco
# 3  332343.61  San Francisco
# 4  326373.19  San Francisco
# ...

# %%
#identifying missvalues from dataset
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36158
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148648
# Agency                   0
# Status              110529
# dtype: int64

# %%
#view missing val in the form of boolean
df.isna().any()
# Out:
# Id                  False
# EmployeeName        False
# JobTitle            False
# BasePay              True
# OvertimePay         False
# OtherPay            False
# Benefits             True
# TotalPay            False
# TotalPayBenefits    False
# Year                False
# Notes                True
# Agency              False
# Status               True
# dtype: bool

# %%
df.head(16)
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                   CAPTAIN III (POLICE DEPARTMENT)
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %%
df.iloc[0:1,0:6]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay
# 0  167411.18          0.0  400184.25

# %%
df.iloc[0:3,0:9]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3  ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91

# %%
df.loc[:,"EmployeeName":"Benefits"]
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148643   Carolyn A Wilson                       Human Services Technician
# 148644     Joann Anderson                     Communications Dispatcher 2
# 148645        Leon Walker                                       Custodian
# 148646      Roy I Tillery                                       Custodian
# 148647          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits
# ...

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
#view the basepay cal for missing val
df["BasePay"].head()
# Out:
# 0    167411.18
# 1    155966.02
# 2    212739.13
# 3     77916.00
# 4    134401.60
# Name: BasePay, dtype: float64

# %%
#calculating mean of basepay
df["BasePay"].mean()
# Out:
# 66325.39811865473

# %%
#filling missing val of basepay col with mean of basepay col
df["BasePay"]=df["BasePay"].fillna(66325)

# %%
#identifying basepay col
df["BasePay"].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148643    False
# 148644    False
# 148645    False
# 148646    False
# 148647    False
# Name: BasePay, Length: 148648, dtype: bool

# %%
import seaborn as sns
sns.boxplot(df["BasePay"])
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BasePay'>

# %%
print("Successfully completed a project on DataManipulation")
# Out:
# Successfully completed a project on DataManipulation

# %%
print("Thank you simplilearn")
# Out:
# Thank you simplilearn
